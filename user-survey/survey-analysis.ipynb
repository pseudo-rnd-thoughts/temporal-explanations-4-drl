# %% [markdown]
# # Analysis of the user survey
#
# 1. Plot the Likert rating for each explanation type and question
# 2. Plot the Likert rating for each environment and user familiarity to the environment
# 3. Plot the contrastive ratings for each explanation type and question

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import TABLEAU_COLORS
from matplotlib.patches import Rectangle

# %%
questions = [
    "From the explanation, I understand how the agent works.",
    "This explanation of how the agent works has sufficient detail.",
    "This explanation of how the agent works is satisfying.",
    "Using the explanation, I can predict the agent's next action"
]
short_questions = [
    "Explanation Understanding",
    "Explanation Detail",
    "Explanation Satisfaction",
    "Predictability of next  action"
]
explanations = [
    "Dataset Similarity Explanation",
    "Skill Explanation",
    "Plan Explanation",
    "Grad-CAM",
    "Perturbation-based Saliency Map"
]
short_explanations = [
    "DSE",
    "SE",
    "PE",
    "Grad-CAM",
    "PBSM"
]

environments = [
    "Breakout",
    "Space Invaders",
    "Seaquest",
]
colours = list(TABLEAU_COLORS.keys())[:5]

# %%
# loading the survey
anonymised_user_survey = pd.read_csv("anonymised-user-info.csv")
individual_survey = pd.read_csv("individual-survey.csv")
contrastive_survey = pd.read_csv("contrastive-survey.csv")

# %%
anonymised_user_survey
# Out:
#     Survey  UserID        TimeTaken             Gender  \
# 0        0       2  0 days 00:10:36                Man
# 1        0       3  0 days 00:15:02                Man
# 2        0       4  0 days 00:12:29              Woman
# 3        0       5  0 days 08:00:16                Man
# 4        0       6  0 days 01:58:12                Man
# 5        0       7  0 days 00:26:22                Man
# 6        1       1  0 days 00:19:56              Woman
# 7        1       2  0 days 00:06:09                Man
# 8        1       3  0 days 00:22:27                Man
# 9        1       4  0 days 00:19:11              Woman
# 10       1       5  0 days 00:30:09              Woman
# 11       1       6  0 days 00:14:43  Prefer not to say
# 12       1       7  0 days 00:19:48                Man
# 13       1       8  0 days 00:14:16                Man
# 14       1       9  0 days 00:17:02                Man
# 15       1      10  0 days 00:16:56              Woman
# 16       1      11  0 days 00:37:22                Man
# 17       1      12  0 days 00:45:44              Woman
# 18       1      13  0 days 00:14:41                Man
# 19       1      14  0 days 00:12:29              Woman
# 20       1      15  0 days 00:10:26              Woman
# 21       1      16  0 days 00:09:09              Woman
# 22       1      17  0 days 00:51:11                Man
# 23       1      18  0 days 00:25:58                Man
# 24       1      19  0 days 00:17:30                Man
# 25       1      20  0 days 00:08:08                Man
#
#                                             Education        DegreeArea  \
# 0                                           Bachelors       Engineering
# 1                                             Masters       Engineering
# 2                                           Doctorate       Engineering
# 3                                             Masters       Engineering
# 4                                             Masters           Science
# 5                                             Masters       Engineering
# 6                                           Bachelors  Business Studies
# 7                                           Bachelors       Engineering
# 8   Various professional qualifications equivalent...       Engineering
# 9                                           Doctorate       Engineering
# 10                                            Masters           Science
# 11                                            Masters           Science
# 12                                          Bachelors           Science
# 13                                          Doctorate       Engineering
# 14                                            Masters       Engineering
# 15                                          Bachelors           Science
# 16                                            Masters       Engineering
# 17                                           A Levels           Science
# 18                                           A Levels       Engineering
# 19                                           A Levels           Science
# 20                                          Bachelors           Science
# 21                                            Masters           Science
# 22                                          Bachelors        Humanities
# 23                                           A Levels       Engineering
# 24                                            Masters       Engineering
# 25                                            Masters           Science
#
#     StudiedAI                                  BreakoutKnowledge  \
# 0        True           Have played and understand the game well
# 1       False           Have played and understand the game well
# 2        True           Have played and understand the game well
# 3        True           Have played and understand the game well
# 4        True  Have played once or twice and have minimal kno...
# 5        True           Have played and understand the game well
# 6       False   Never played and have no idea how the game works
# 7        True           Have played and understand the game well
# 8        True           Have played and understand the game well
# 9        True  Have played once or twice and have minimal kno...
# 10       True  Have played once or twice and have minimal kno...
# 11       True           Have played and understand the game well
# 12       True           Have played and understand the game well
# 13       True           Have played and understand the game well
# 14       True           Have played and understand the game well
# 15      False   Never played and have no idea how the game works
# 16       True           Have played and understand the game well
# 17      False           Have played and understand the game well
# 18       True           Have played and understand the game well
# 19       True  Have played once or twice and have minimal kno...
# 20       True   Never played and have no idea how the game works
# 21      False           Have played and understand the game well
# 22      False  Have played once or twice and have minimal kno...
# 23      False  Have played once or twice and have minimal kno...
# 24       True           Have played and understand the game well
# 25       True           Have played and understand the game well
#
#     BreakoutKnowledgeScore                             SpaceInvadersKnowledge  \
# 0                        3           Have played and understand the game well
# 1                        3           Have played and understand the game well
# 2                        3           Have played and understand the game well
# 3                        3  Have played once or twice and have minimal kno...
# 4                        2  Have played once or twice and have minimal kno...
# 5                        3           Have played and understand the game well
# 6                        1  Have played once or twice and have minimal kno...
# 7                        3           Have played and understand the game well
# 8                        3           Have played and understand the game well
# 9                        2           Have played and understand the game well
# 10                       2  Have played once or twice and have minimal kno...
# 11                       3           Have played and understand the game well
# 12                       3           Have played and understand the game well
# 13                       3           Have played and understand the game well
# 14                       3  Have played once or twice and have minimal kno...
# 15                       1  Have played once or twice and have minimal kno...
# 16                       3  Have played once or twice and have minimal kno...
# 17                       3  Have played once or twice and have minimal kno...
# 18                       3           Have played and understand the game well
# 19                       2  Have played once or twice and have minimal kno...
# 20                       1  Have played once or twice and have minimal kno...
# 21                       3   Never played and have no idea how the game works
# 22                       2  Have played once or twice and have minimal kno...
# 23                       2  Have played once or twice and have minimal kno...
# 24                       3  Have played once or twice and have minimal kno...
# 25                       3  Have played once or twice and have minimal kno...
#
#     SpaceInvadersKnowledgeScore  \
# 0                             3
# 1                             3
# 2                             3
# 3                             2
# 4                             2
# 5                             3
# 6                             2
# 7                             3
# 8                             3
# 9                             3
# 10                            2
# 11                            3
# 12                            3
# 13                            3
# 14                            2
# 15                            2
# 16                            2
# 17                            2
# 18                            3
# 19                            2
# 20                            2
# 21                            1
# 22                            2
# 23                            2
# 24                            2
# 25                            2
#
#                                     SeaquestKnowledge  SeaquestKnowledgeScore
# 0            Have played and understand the game well                       3
# 1    Never played and have no idea how the game works                       1
# 2            Have played and understand the game well                       3
# 3    Never played and have no idea how the game works                       1
# 4    Never played and have no idea how the game works                       1
# 5    Never played and have no idea how the game works                       1
# 6    Never played and have no idea how the game works                       1
# 7    Never played and have no idea how the game works                       1
# 8    Never played and have no idea how the game works                       1
# 9   Have played once or twice and have minimal kno...                       2
# 10   Never played and have no idea how the game works                       1
# 11  Have played once or twice and have minimal kno...                       2
# 12  Have played once or twice and have minimal kno...                       2
# 13   Never played and have no idea how the game works                       1
# 14   Never played and have no idea how the game works                       1
# 15   Never played and have no idea how the game works                       1
# 16   Never played and have no idea how the game works                       1
# 17   Never played and have no idea how the game works                       1
# 18  Have played once or twice and have minimal kno...                       2
# 19   Never played and have no idea how the game works                       1
# 20   Never played and have no idea how the game works                       1
# 21   Never played and have no idea how the game works                       1
# 22   Never played and have no idea how the game works                       1
# 23   Never played and have no idea how the game works                       1
# 24   Never played and have no idea how the game works                       1
# 25   Never played and have no idea how the game works                       1

# %%
individual_survey
# Out:
#       Survey  UserID                 ExplanationType  \
# 0          1       2  Dataset Similarity Explanation
# 1          1       2  Dataset Similarity Explanation
# 2          1       2  Dataset Similarity Explanation
# 3          1       2  Dataset Similarity Explanation
# 4          1       2  Dataset Similarity Explanation
# ...      ...     ...                             ...
# 1555       2      20                Plan Explanation
# 1556       2      20                Plan Explanation
# 1557       2      20                Plan Explanation
# 1558       2      20                Plan Explanation
# 1559       2      20                Plan Explanation
#
#                                            QuestionType  QuestionNumber  \
# 0     From the explanation, I understand how the age...               0
# 1     This explanation of how the agent works has su...               0
# 2     This explanation of how the agent works is sat...               0
# 3     Using the explanation, I can predict the agent...               0
# 4     From the explanation, I understand how the age...               1
# ...                                                 ...             ...
# 1555  This explanation of how the agent works has su...              13
# 1556  This explanation of how the agent works has su...              14
# 1557  Using the explanation, I can predict the agent...              14
# 1558  This explanation of how the agent works is sat...              14
# 1559  Using the explanation, I can predict the agent...              14
#
#         Environment          Answer  LikertRating
# 0          Breakout  Strongly Agree             5
# 1          Breakout           Agree             4
# 2          Breakout           Agree             4
# 3          Breakout         Neutral             3
# 4     SpaceInvaders        Disagree             2
# ...             ...             ...           ...
# 1555  SpaceInvaders  Strongly Agree             5
# 1556       Seaquest  Strongly Agree             5
# 1557       Seaquest  Strongly Agree             5
# 1558       Seaquest  Strongly Agree             5
# 1559       Seaquest  Strongly Agree             5
#
# [1560 rows x 8 columns]

# %%
contrastive_survey
# Out:
#      Survey  UserID                                       QuestionType  \
# 0         1       2  From the explanation, I understand how the age...
# 1         1       2  This explanation of how the agent works has su...
# 2         1       2  This explanation of how the agent works is sat...
# 3         1       2  From the explanation, I can predict the agent'...
# 4         1       2  From the explanation, I understand how the age...
# ..      ...     ...                                                ...
# 931       2      20  From the explanation, I can predict the agent'...
# 932       2      20  From the explanation, I understand how the age...
# 933       2      20  This explanation of how the agent works has su...
# 934       2      20  This explanation of how the agent works is sat...
# 935       2      20  From the explanation, I can predict the agent'...
#
#      QuestionNum    Environment                    Explanation1  \
# 0              0       Breakout                Plan Explanation
# 1              0       Breakout                Plan Explanation
# 2              0       Breakout                Plan Explanation
# 3              0       Breakout                Plan Explanation
# 4              1       Breakout  Dataset Similarity Explanation
# ..           ...            ...                             ...
# 931            7       Breakout                        Grad-CAM
# 932            8  SpaceInvaders                        Grad-CAM
# 933            8  SpaceInvaders                        Grad-CAM
# 934            8  SpaceInvaders                        Grad-CAM
# 935            8  SpaceInvaders                        Grad-CAM
#
#                         Explanation2  \
# 0    Perturbation-based Saliency Map
# 1    Perturbation-based Saliency Map
# 2    Perturbation-based Saliency Map
# 3    Perturbation-based Saliency Map
# 4                  Skill Explanation
# ..                               ...
# 931                Skill Explanation
# 932   Dataset Similarity Explanation
# 933   Dataset Similarity Explanation
# 934   Dataset Similarity Explanation
# 935   Dataset Similarity Explanation
#
#                                                 Answer  AnswerNum  \
# 0    This is more true for explanation 1 than expla...          1
# 1    This is more true for explanation 1 than expla...          1
# 2    This is more true for explanation 1 than expla...          1
# 3    This is more true for explanation 1 than expla...          1
# 4         This is equally true for explanation 1 and 2          3
# ..                                                 ...        ...
# 931  This is more true for explanation 2 than expla...          2
# 932  This is more true for explanation 1 than expla...          1
# 933  This is more true for explanation 1 than expla...          1
# 934  This is more true for explanation 1 than expla...          1
# 935  This is more true for explanation 1 than expla...          1
#
#                 OrderedExplanation1              OrderedExplanation2  \
# 0                  Plan Explanation  Perturbation-based Saliency Map
# 1                  Plan Explanation  Perturbation-based Saliency Map
# 2                  Plan Explanation  Perturbation-based Saliency Map
# 3                  Plan Explanation  Perturbation-based Saliency Map
# 4                 Skill Explanation   Dataset Similarity Explanation
# ..                              ...                              ...
# 931                        Grad-CAM                Skill Explanation
# 932  Dataset Similarity Explanation                         Grad-CAM
# 933  Dataset Similarity Explanation                         Grad-CAM
# 934  Dataset Similarity Explanation                         Grad-CAM
# 935  Dataset Similarity Explanation                         Grad-CAM
#
#                                          OrderedAnswer  OrderedAnswerNum
# 0    This is more true for explanation 1 than expla...                 1
# 1    This is more true for explanation 1 than expla...                 1
# 2    This is more true for explanation 1 than expla...                 1
# 3    This is more true for explanation 1 than expla...                 1
# 4         This is equally true for explanation 1 and 2                 3
# ..                                                 ...               ...
# 931  This is more true for explanation 2 than expla...                 2
# 932  This is more true for explanation 2 than expla...                 2
# 933  This is more true for explanation 2 than expla...                 2
# 934  This is more true for explanation 2 than expla...                 2
# 935  This is more true for explanation 2 than expla...                 2
#
# [936 rows x 13 columns]

# %%
# Individual Explanation Ratings
fig, axs = plt.subplots(ncols=len(questions), figsize=(14, 3.5))
# fig.suptitle("Likert ratings for each question in the Individual Explanation survey", fontsize=14)

plots = []
for ax, question, short_question in zip(axs, questions, short_questions):
    ax.set_title(short_question)
    # ax.set_ylabel("Average Likert Rating")
    ax.set_yticks(np.arange(1, 6), labels=""*5)

    data = individual_survey[individual_survey["QuestionType"] == question].groupby("ExplanationType")["LikertRating"].apply(list).reindex(explanations)
    plots.append(ax.boxplot(data, labels=short_explanations, patch_artist=True, notch=True))

axs[0].set_ylabel("Likert Rating")
axs[0].set_yticks(np.arange(1, 6), labels=["Strongly\nDisagree", "Disagree", "Neutral", "Agree", "Strongly\nAgree"])
for bplot in plots:
    for patch, colour in zip(bplot['boxes'], TABLEAU_COLORS):
        patch.set_facecolor(colour)

legend = fig.legend(plots[0]["boxes"], explanations, loc="lower center", ncol=len(short_explanations),
                    bbox_to_anchor=(.5, -0.07))
        
plt.tight_layout()
plt.savefig('figs/survey/individual-evaluation.pdf',
            bbox_extra_artists=(legend,), bbox_inches='tight')
plt.savefig('figs/survey/individual-evaluation.png',
            bbox_extra_artists=(legend,), bbox_inches='tight')

# %%
# Environment familiarity with explanation evaluation
fig, axs = plt.subplots(ncols=1 + len(environments), figsize=(16, 3.5))
# fig.suptitle("The Likert Rating for each Environment and Explanation Type along with familiarity.", fontsize=14)

axs[0].set_title("Prior User Knowledge about Environment")
# axs[0].set_ylabel("")
axs[0].set_yticks([1, 2, 3], labels=["Unfamiliar", "Familiar", "Experienced"], rotation=30)
data = [
    anonymised_user_survey[col]
    for col in ["BreakoutKnowledgeScore", "SpaceInvadersKnowledgeScore", "SeaquestKnowledgeScore"]
]
env_plot = axs[0].boxplot(data, labels=["Breakout", "Space\nInvaders", "Seaquest"], patch_artist=True, notch=True)

for patch, colour in zip(env_plot['boxes'], ["tab:pink", "tab:olive", "navy"]):
    patch.set_facecolor(colour)

plots = []
for i, (ax, env) in enumerate(zip(axs[1:], environments)):
    ax.set_title(f'Environment: {env}')
    ax.set_yticks(np.arange(1, 6), labels=[""] * 5)

    data = individual_survey[individual_survey["QuestionNumber"] % 3 == i].groupby("ExplanationType")["LikertRating"].apply(list).reindex(explanations)
    plots.append(ax.boxplot(data, labels=short_explanations, patch_artist=True, notch=True))

axs[1].set_ylabel("Likert Rating")
axs[1].set_yticks(np.arange(1, 6), labels=["Strongly\nDisagree", "Disagree", "Neutral", "Agree", "Strongly\nAgree"])

for bplot in plots:
    for patch, colour in zip(bplot['boxes'], TABLEAU_COLORS):
        patch.set_facecolor(colour)

legend = fig.legend(plots[0]["boxes"], explanations, loc="lower center", ncol=len(short_explanations),
                    bbox_to_anchor=(.5, -0.07))

plt.tight_layout()
plt.savefig('figs/survey/environment-individual-evaluation.pdf', bbox_extra_artists=(legend,), bbox_inches='tight')
plt.savefig('figs/survey/environment-individual-evaluation.png', bbox_extra_artists=(legend,), bbox_inches='tight')

# %%
contrastive_survey["QuestionType"].unique()
# Out:
# array(['From the explanation, I understand how the agent works.',
#        'This explanation of how the agent works has sufficient detail.',
#        'This explanation of how the agent works is satisfying.',
#        "From the explanation, I can predict the agent's next action"],
#       dtype=object)

# %%
# Contrastive preference
fig, axs = plt.subplots(ncols=len(questions), figsize=(14, 4))
# fig.suptitle("Preference of Explanations", fontsize=14)

contrastive_questions = [
    "From the explanation, I understand how the agent works.",
    "This explanation of how the agent works has sufficient detail.",
    "This explanation of how the agent works is satisfying.",
    "From the explanation, I can predict the agent's next action",
]
for ax, question, short_question in zip(axs, contrastive_questions, short_questions):
    ax.set_title(short_question)

    preferences = np.zeros((len(short_explanations), len(short_explanations)))
    data = contrastive_survey[contrastive_survey["QuestionType"] == question].groupby(["OrderedExplanation1", "OrderedExplanation2"], group_keys=True)["OrderedAnswerNum"].apply(list)
    for (explanation_1, explanation_2), explanation_preferences in data.items():
        index_1 = explanations.index(explanation_1)
        index_2 = explanations.index(explanation_2)

        length = len(explanation_preferences)
        explanation_1_preference = sum(pref == 1 for pref in explanation_preferences) / length
        explanation_2_preference = sum(pref == 2 for pref in explanation_preferences) / length

        preferences[index_1, index_2] = explanation_1_preference
        preferences[index_2, index_1] = explanation_2_preference

    cmap = ax.imshow(preferences, cmap="autumn_r")

    # ax.xaxis.set_ticks_position('top') # the rest is the same
    ax.set_xticks(np.arange(len(short_explanations)), labels=short_explanations)
    ax.set_yticks(np.arange(len(short_explanations)), labels=short_explanations)
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

    for i in range(len(short_explanations)):
        for j in range(len(short_explanations)):
            if i != j and not ({i, j} == {1, 2}):
                ax.text(j, i, f'{preferences[i, j] * 100:.0f}%', ha="center", va="center", color="black", fontsize=11)
            else:
                ax.text(j, i, f'-', ha="center", va="center", color="black", fontsize=11)

r = Rectangle((0,0), 1, 1, fill=False, edgecolor='none', visible=False)
legend = fig.legend([r] * len(explanations),
                    [f'{short_explanation}: {explanation}' if short_explanation != explanation else explanation for short_explanation, explanation in zip(short_explanations, explanations)],
                    loc="lower center", ncol=len(short_explanations),bbox_to_anchor=(.5, -0.07))

# cb_ax = fig.add_axes([.91,.124,.04,.754])
# plt.colorbar(cmap)

plt.tight_layout()
plt.savefig('figs/survey/contrastive-evaluation.pdf', bbox_extra_artists=(legend,), bbox_inches='tight')
plt.savefig('figs/survey/contrastive-evaluation.png', bbox_extra_artists=(legend,), bbox_inches='tight')

# %%
contrastive_survey[(contrastive_survey["QuestionType"] == contrastive_questions[0])
                  ].groupby(["OrderedExplanation1", "OrderedExplanation2", "OrderedAnswer"], group_keys=True)["Answer"].count().reset_index(name="count")
# Out:
#                 OrderedExplanation1              OrderedExplanation2  \
# 0    Dataset Similarity Explanation                         Grad-CAM
# 1    Dataset Similarity Explanation                         Grad-CAM
# 2    Dataset Similarity Explanation                         Grad-CAM
# 3    Dataset Similarity Explanation  Perturbation-based Saliency Map
# 4    Dataset Similarity Explanation  Perturbation-based Saliency Map
# 5    Dataset Similarity Explanation  Perturbation-based Saliency Map
# 6    Dataset Similarity Explanation                 Plan Explanation
# 7    Dataset Similarity Explanation                 Plan Explanation
# 8    Dataset Similarity Explanation                 Plan Explanation
# 9    Dataset Similarity Explanation                Skill Explanation
# 10   Dataset Similarity Explanation                Skill Explanation
# 11                         Grad-CAM   Dataset Similarity Explanation
# 12                         Grad-CAM   Dataset Similarity Explanation
# 13                         Grad-CAM   Dataset Similarity Explanation
# 14                         Grad-CAM  Perturbation-based Saliency Map
# 15                         Grad-CAM  Perturbation-based Saliency Map
# 16                         Grad-CAM  Perturbation-based Saliency Map
# 17                         Grad-CAM                 Plan Explanation
# 18                         Grad-CAM                 Plan Explanation
# 19                         Grad-CAM                Skill Explanation
# 20                         Grad-CAM                Skill Explanation
# 21                         Grad-CAM                Skill Explanation
# 22  Perturbation-based Saliency Map   Dataset Similarity Explanation
# 23  Perturbation-based Saliency Map   Dataset Similarity Explanation
# 24  Perturbation-based Saliency Map                         Grad-CAM
# 25  Perturbation-based Saliency Map                         Grad-CAM
# 26  Perturbation-based Saliency Map                         Grad-CAM
# 27  Perturbation-based Saliency Map                 Plan Explanation
# 28  Perturbation-based Saliency Map                 Plan Explanation
# 29  Perturbation-based Saliency Map                Skill Explanation
# 30  Perturbation-based Saliency Map                Skill Explanation
# 31  Perturbation-based Saliency Map                Skill Explanation
# 32                 Plan Explanation   Dataset Similarity Explanation
# 33                 Plan Explanation   Dataset Similarity Explanation
# 34                 Plan Explanation   Dataset Similarity Explanation
# 35                 Plan Explanation                         Grad-CAM
# 36                 Plan Explanation  Perturbation-based Saliency Map
# 37                Skill Explanation   Dataset Similarity Explanation
# 38                Skill Explanation   Dataset Similarity Explanation
# 39                Skill Explanation   Dataset Similarity Explanation
# 40                Skill Explanation                         Grad-CAM
# 41                Skill Explanation  Perturbation-based Saliency Map
# 42                Skill Explanation  Perturbation-based Saliency Map
#
#                                         OrderedAnswer  count
# 0        This is equally true for explanation 1 and 2      2
# 1   This is more true for explanation 1 than expla...      3
# 2   This is more true for explanation 2 than expla...     15
# 3        This is equally true for explanation 1 and 2      2
# 4   This is more true for explanation 1 than expla...      3
# 5   This is more true for explanation 2 than expla...     15
# 6        This is equally true for explanation 1 and 2      4
# 7   This is more true for explanation 1 than expla...     13
# 8   This is more true for explanation 2 than expla...      3
# 9        This is equally true for explanation 1 and 2     17
# 10  This is more true for explanation 1 than expla...      3
# 11       This is equally true for explanation 1 and 2      1
# 12  This is more true for explanation 1 than expla...      1
# 13  This is more true for explanation 2 than expla...      4
# 14       This is equally true for explanation 1 and 2      6
# 15  This is more true for explanation 1 than expla...     11
# 16  This is more true for explanation 2 than expla...      3
# 17  This is more true for explanation 1 than expla...     19
# 18  This is more true for explanation 2 than expla...      1
# 19       This is equally true for explanation 1 and 2      1
# 20  This is more true for explanation 1 than expla...      1
# 21  This is more true for explanation 2 than expla...     18
# 22  This is more true for explanation 1 than expla...      2
# 23  This is more true for explanation 2 than expla...      4
# 24       This is equally true for explanation 1 and 2      1
# 25  This is more true for explanation 1 than expla...      1
# 26  This is more true for explanation 2 than expla...      4
# 27  This is more true for explanation 1 than expla...     19
# 28  This is more true for explanation 2 than expla...      1
# 29       This is equally true for explanation 1 and 2      1
# 30  This is more true for explanation 1 than expla...     17
# 31  This is more true for explanation 2 than expla...      2
# 32       This is equally true for explanation 1 and 2      1
# 33  This is more true for explanation 1 than expla...      4
# 34  This is more true for explanation 2 than expla...      1
# 35  This is more true for explanation 1 than expla...      6
# 36  This is more true for explanation 1 than expla...      6
# 37       This is equally true for explanation 1 and 2      3
# 38  This is more true for explanation 1 than expla...      1
# 39  This is more true for explanation 2 than expla...      2
# 40  This is more true for explanation 1 than expla...      6
# 41  This is more true for explanation 1 than expla...      5
# 42  This is more true for explanation 2 than expla...      1

# %% [markdown]
# # Paper values

# %%
anonymised_user_survey[["BreakoutKnowledgeScore", "SpaceInvadersKnowledgeScore", "SeaquestKnowledgeScore"]].mean()
# Out:
# BreakoutKnowledgeScore         2.538462
# SpaceInvadersKnowledgeScore    2.384615
# SeaquestKnowledgeScore         1.307692
# dtype: float64

# %%
individual_survey.groupby(["ExplanationType"])["LikertRating"].mean()
# Out:
# ExplanationType
# Dataset Similarity Explanation     3.516026
# Grad-CAM                           2.512821
# Perturbation-based Saliency Map    2.573718
# Plan Explanation                   4.041667
# Skill Explanation                  3.336538
# Name: LikertRating, dtype: float64

# %%
individual_survey.groupby(["ExplanationType", "Environment"])["LikertRating"].agg(["mean", "var"])
# Out:
#                                                    mean       var
# ExplanationType                 Environment
# Dataset Similarity Explanation  Breakout       3.548077  1.298637
#                                 Seaquest       3.567308  1.257562
#                                 SpaceInvaders  3.432692  1.451736
# Grad-CAM                        Breakout       2.682692  1.131348
#                                 Seaquest       2.240385  1.038742
#                                 SpaceInvaders  2.615385  1.306945
# Perturbation-based Saliency Map Breakout       2.701923  1.279220
#                                 Seaquest       2.394231  1.464432
#                                 SpaceInvaders  2.625000  1.382282
# Plan Explanation                Breakout       3.892857  1.060671
#                                 Seaquest       4.032258  1.267244
#                                 SpaceInvaders  4.173077  0.998880
# Skill Explanation               Breakout       3.278846  1.076830
#                                 Seaquest       3.528846  1.008869
#                                 SpaceInvaders  3.201923  1.211258

# %%
individual_survey.groupby(["ExplanationType", "QuestionType"])["LikertRating"].agg(["mean", "var"])
# Out:
#                                                                                         mean  \
# ExplanationType                 QuestionType
# Dataset Similarity Explanation  From the explanation, I understand how the agen...  3.692308
#                                 This explanation of how the agent works has suf...  3.320513
#                                 This explanation of how the agent works is sati...  3.397436
#                                 Using the explanation, I can predict the agent'...  3.653846
# Grad-CAM                        From the explanation, I understand how the agen...  2.628205
#                                 This explanation of how the agent works has suf...  2.384615
#                                 This explanation of how the agent works is sati...  2.602564
#                                 Using the explanation, I can predict the agent'...  2.435897
# Perturbation-based Saliency Map From the explanation, I understand how the agen...  2.705128
#                                 This explanation of how the agent works has suf...  2.512821
#                                 This explanation of how the agent works is sati...  2.692308
#                                 Using the explanation, I can predict the agent'...  2.384615
# Plan Explanation                From the explanation, I understand how the agen...  4.192308
#                                 This explanation of how the agent works has suf...  3.923077
#                                 This explanation of how the agent works is sati...  4.025641
#                                 Using the explanation, I can predict the agent'...  4.025641
# Skill Explanation               From the explanation, I understand how the agen...  3.551282
#                                 This explanation of how the agent works has suf...  3.102564
#                                 This explanation of how the agent works is sati...  3.192308
#                                 Using the explanation, I can predict the agent'...  3.500000
#
#                                                                                          var
# ExplanationType                 QuestionType
# Dataset Similarity Explanation  From the explanation, I understand how the agen...  1.072927
#                                 This explanation of how the agent works has suf...  1.415418
#                                 This explanation of how the agent works is sati...  1.463370
#                                 Using the explanation, I can predict the agent'...  1.320180
# Grad-CAM                        From the explanation, I understand how the agen...  1.275558
#                                 This explanation of how the agent works has suf...  1.148851
#                                 This explanation of how the agent works is sati...  1.073760
#                                 Using the explanation, I can predict the agent'...  1.262071
# Perturbation-based Saliency Map From the explanation, I understand how the agen...  1.431402
#                                 This explanation of how the agent works has suf...  1.266067
#                                 This explanation of how the agent works is sati...  1.410589
#                                 Using the explanation, I can predict the agent'...  1.408591
# Plan Explanation                From the explanation, I understand how the agen...  0.858641
#                                 This explanation of how the agent works has suf...  1.266733
#                                 This explanation of how the agent works is sati...  1.116217
#                                 Using the explanation, I can predict the agent'...  1.272061
# Skill Explanation               From the explanation, I understand how the agen...  0.951881
#                                 This explanation of how the agent works has suf...  1.106227
#                                 This explanation of how the agent works is sati...  1.222278
#                                 Using the explanation, I can predict the agent'...  1.058442

# %%
fig, ax = plt.subplots(figsize=(5.5, 3))

data = individual_survey.groupby(["UserID", "ExplanationType"])["LikertRating"].agg(["var"])\
    .groupby("ExplanationType")["var"].apply(list).reindex(explanations)
ax.hist(data, stacked=True, label=explanations, bins=20)
ax.set_xlabel("User Variance for each Explanation Type", fontsize=11)
ax.set_ylabel("Frequency", fontsize=11)
ax.legend()

plt.tight_layout()
plt.savefig('figs/survey/explanation-variances.png')
plt.savefig('figs/survey/explanation-variances.pdf')

# %%
data = individual_survey.groupby(["UserID", "ExplanationType"])["LikertRating"].agg(["var"])
f'Average variance is {sum(data["var"] < 1.0) / len(data)}'
# Out:
# 0.79

# %%
data = individual_survey.groupby(["UserID", "ExplanationType"])["LikertRating"].agg(["var"])\
    .groupby("ExplanationType")["var"].quantile(q=[0.2, 0.4, 0.6, 0.75, 0.8])
data = data.to_frame().reset_index().rename(columns={"level_1": "Quantile", "var": "Variance"})

data.pivot(index="ExplanationType", columns="Quantile", values="Variance")
# Out:
# Quantile                             0.20      0.40      0.60      0.75  \
# ExplanationType
# Dataset Similarity Explanation   0.137681  0.728788  0.978788  1.290308
# Grad-CAM                         0.066667  0.356752  0.701515  0.881917
# Perturbation-based Saliency Map  0.115942  0.411067  0.628788  0.740077
# Plan Explanation                 0.163636  0.242424  0.373188  0.589015
# Skill Explanation                0.033333  0.446970  0.780369  0.892045
#
# Quantile                             0.80
# ExplanationType
# Dataset Similarity Explanation   1.651812
# Grad-CAM                         0.892391
# Perturbation-based Saliency Map  0.884848
# Plan Explanation                 1.018577
# Skill Explanation                1.173518
